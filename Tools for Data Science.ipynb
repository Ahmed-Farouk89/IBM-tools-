# %% [markdown]
# # Tools for Data Science

# %% [markdown]
# #### This notebook is made to solve all the Exercises in the final assignment

# %% [markdown]
# ### Data science languages
# - python
# - R
# - SQL

# %% [markdown]
# ### Data science libraries
# - Numpy
# - Matplotlib
# - Pandas
# - SciKit-Learn

# %% [markdown]
# ### Tools
#
#
# | Jupyter Notebook | Apache Spark | TensorFlow |
# | --- | --- | --- |
# | Writing | big data workloads | Machine Learning |

# %% [markdown]
# Examples of arithmetic expression is:<br>
# - 3+2
# - 3*3

# %%
def sum (x,y):
    z= x+y
    print('the sum is:',z)
def mult(x,y):
    z= x*y
    print('The multiplication is:',z)
    
sum(3,2)
mult(3,3)
# Out:
# the sum is: 5
# The multiplication is: 9

# %%
def convert(x):
    y= x/60
    print(x, 'minutes is equal to', y, 'hours')
convert(150)
# Out:
# 150 minutes is equal to 2.5 hours

# %% [markdown]
# ## Objectives
# 1. learn to use jupyter
# 1. know about languages
# 1. know about libraries
# 1. know about Different tools

# %% [markdown]
# #### Ahmed Farouk Abobakr Ali
